# %% [markdown]
# # Задачи попроще

# %% [markdown]
# ## 1. Средний балл (списки)
#
# Дан список `student = ('Иван Питонов', 2001, [8, 7, 7, 9, 6], True)`. Выполните пункты ниже. Все выводы должны быть в формате "Средний балл студента: {средний балл}"
#
# 1. Выведите фамилию и имя Ивана в формате "Студент: {Фамилия}, {Имя}"
# 2. Выведите возраст Ивана, если сейчас 2020 год.
# 3. Напечатайте оценки Ивана через запятую.
# 1. Найдите средний балл Ивана, если оценки хранятся в списке внутри кортежа. Сумму элементов списка можно найти с помощью функции sum(). Выведите средний балл.
# 3. Если средняя оценка Ивана больше или равна 8, то он получает повышенную стипендию. Выведите True или False.

# %%
# ваше решение здесь
import re
student = ('Иван Питонов', 2001, [8, 7, 7, 9, 6], True)
name = student[0].split()
print ('Студент:', name[1], name[0])
print ('Возраст:', 2020 - student[1])
print ('Оценки:', ','.join(map(str, student[2])))
srb = sum(student[2])/len(student[2])
print ('Средний балл:', srb)
if srb >= 8:
    print ('Возможность получения повышенной стипендии:', 'True')
else:
    print ('Возможность получения повышенной стипендии:', 'False')
# Out:
# Студент: Питонов Иван
# Возраст: 19
# Оценки: 8,7,7,9,6
# Средний балл: 7.4
# Возможность получения повышенной стипендии: False

# %% [markdown]
# ## 2. Сортируем числа и строки (списки, сортировки, map())
# Дан список `numbers = [1, 1000, 1002124, 25, 10, 20, 351]`. Выполните следующие шаги. Для сортировок пользуйтесь функцией sorted().
#
# 1. Отсортируйте этот список по возрастанию и сохраните результат в переменную numbers_int_sorted
# 2. На основе оригинального списка numbers с помощью функции map создайте новый список, где вместо каждого числа будет строка ('1', '1000' и т.д.) и сохраните его в переменную numbers_str
# 3. Отсортируйте список numbers_str по возрастанию и сохраните результат в переменную numbers_str_sorted
# 4. Отсортийте список numbers_str по возрастанию с помощью ключа, который перед сортировкой представляет строки в виде целых чисел, и сохраните результат в переменную numbers_str_key_sorted
# 5. Выведите три отсортированных списка. Есть ли среди них одинаковые? Почему?

# %%
# ваше решение здесь
numbers = [1, 1000, 1002124, 25, 10, 20, 351]
numbers_int_sorted = sorted(numbers)
print (numbers_int_sorted)
numbers_str = list(map(str, numbers))
numbers_str_sorted = sorted(numbers_str)
numbers_str_key_sorted = sorted(numbers_str, key=int)
print (numbers_str_sorted)
print (numbers_str_key_sorted)
# При преобразовании строк в целые числа перед сортировкой, сортировка выполняется, как с целыми числами
# Out:
# [1, 10, 20, 25, 351, 1000, 1002124]
# ['1', '10', '1000', '1002124', '20', '25', '351']
# ['1', '10', '20', '25', '351', '1000', '1002124']

# %% [markdown]
# ## 3. Количество различных чисел (списки и множества)
#
# Дан список чисел, который может содержать до 100000 чисел. Определите, сколько в нем встречается различных чисел.
#
# #### Пример 1
#
# ##### Ввод
#
# 1 2 3 2 1
#
# ##### Вывод
#
# 3
#
# #### Пример 2
# ##### Ввод
#
# 1 2 3 4 5 1 2 1 2 7 3
#
# ##### Вывод
# 6

# %%
# ваше решение здесь
numbers = [1, 2, 3, 2, 1]
x = len(numbers) - len(set(numbers)) + 1
print('Число различных чисел равно:', x)
# Out:
# Число различных чисел равно: 3

# %% [markdown]
# ## 4. Факультативы (множества)
# Группа из 3 студентов пишет заявки на желаемые факультативы из списка: английский, немецкий, право, математика, сольфеджио. Факультатив откроют, если на него запишутся все студенты. Каждый студент может выбрать минимум один и максимум три факультатива. Нужно посчитать количество факультативов, которые откроются.
#
# *Пример*
#
# **Ввод:**
#
# английский сольфеджио право
# математика сольфеджио
# немецкий право
#
# **Вывод:**
#
# 0
#
# **Ввод:**
#
# математика немецкий право
# математика немецкий
# немецкий право математика
#
# **Вывод:**
# 2

# %%
# ваше решение здесь
ft = ['английский', 'немецкий', 'право', 'математика', 'сольфеджио']
print ('Список факультативов:', ', '.join(ft))
print ('Введите названия выбранных первым студентом факультативов через пробел (от 1 до 3)')
a = set(input().split())
print ('Введите названия выбранных вторым студентом факультативов через пробел (от 1 до 3)')
b = set(input().split())
print ('Введите названия выбранных третьим студентом факультативов через пробел (от 1 до 3)')
c = set(input().split())
i = 0
count = 0
while i < len(ft):
    if ft[i] in a and ft[i] in b and ft[i] in c:
        count += 1
    i += 1
print ('Количество открытых факультативов:', count)
# Out:
# Список факультативов: английский, немецкий, право, математика, сольфеджио
# Введите названия выбранных первым студентом факультативов через пробел (от 1 до 3)
#  математика немецкий право
# Введите названия выбранных вторым студентом факультативов через пробел (от 1 до 3)
#  математика немецкий
# Введите названия выбранных третьим студентом факультативов через пробел (от 1 до 3)
#  немецкий право математика
# Количество открытых факультативов: 2

# %% [markdown]
# Давайте модифицируем эту задачу, и представим, что только два студента выбирают факультативы, откроются факультативы, которые выбрал, хотя бы один студент. Но затем выясняется, что один из факультативов из списка отменили. Выводить будет через запятую те факультативы, которые откроются.
#
# *Пример*
# **Ввод:**
#
# математика немецкий право
# математика английский
# право
#
# **Вывод:**
# математика, немецкий, английский

# %%
# ваше решение здесь
ft = ['английский', 'немецкий', 'право', 'математика', 'сольфеджио']
print ('Список факультативов:', ', '.join(ft))
print ('Введите названия выбранных первым студентом факультативов через пробел (от 1 до 3)')
in1 = set(input().split())
print ('Введите названия выбранных вторым студентом факультативов через пробел (от 1 до 3)')
in2 = set(input().split())
print ('Введите отмененный факультатив')
f = set([input()])
lst = (in1 | in2) - f
print ('Список открытых факультативов:', ', '.join(lst))
# Out:
# Список факультативов: английский, немецкий, право, математика, сольфеджио
# Введите названия выбранных первым студентом факультативов через пробел (от 1 до 3)
#  математика немецкий право
# Введите названия выбранных вторым студентом факультативов через пробел (от 1 до 3)
#  математика английский
# Введите отмененный факультатив
#  право
# Список открытых факультативов: математика, немецкий, английский

# %% [markdown]
# ## 5. Вложенные словари
#
# Вам дан словарь, содержащий в себе списки словарей. Напишите код, который выведет на экран 'разработчик' из списка ключа Windows в в первом словаре из списка 2.

# %%
dict_of_lists = {'Список1': [{'Python': 'язык программирования'}, {'R':'язык программирования', 'LaTEX' : 'язык верстки' }], 
                 'Список2' : [{'Windows' : ['операционная система', 'разработчик'], 'UNIX' : 'операционная система'},
                              {'IBM': ['компания-производитель', 'разработчик'], 'IPv6' : 'интернет-протокол' }]}

# ваше решение здесь
print (dict_of_lists['Список2'][0]['Windows'][1])
# Out:
# разработчик

# %% [markdown]
# ## 6. Срезы строк
#
# Напоминание про работу со строками:
#
# len(s) - определить длину строки s
#
# s[i] - получить i-ый символ строки (нумерация с нуля, i - положительное), в случае отрицательного i нумерация идет справа-налево, начиная с -1, например, s[-1] - это последний символ строки
#
# s[i:j] - получить все символы с i-го включительно по j-ый не включительно
#
# s[:i] - все символы до i-го не включительно
#
# s[i:] - все символы, начиная с i-го включительно
#
# s[i:j:k] - все символы с i-го включитель по j-ый не включительно с шагом k, если шаг отрицательный, то i должно указывать на символ стоящий правее, чем j
#
# **Задача:**
#
# Дана строка.
# 1. Сначала выведите третий символ этой строки (считая, что нумерация символов начинается с 1).
# 2. Во второй строке выведите предпоследний символ этой строки.
# 3. В третьей строке выведите первые пять символов этой строки.
# 4. В четвертой строке выведите всю строку, кроме последних двух символов.
# 5. В пятой строке выведите все символы с четными индексами (считая, что индексация начинается с 0).
# 6. В шестой строке выведите все символы с нечетными индексами (считая, что индексация начинается с 0).
# 7. В седьмой строке выведите все символы в обратном порядке.
# 8. В восьмой строке выведите все символы строки через один в обратном порядке, начиная с последнего.
# 9. В девятой строке выведите длину данной строки.
#
# **Ввод:**
# Abrakadabra
#
# **Вывод:**
#
# r
# r
# Abrak
# Abrakadab
# Arkdba
# baaar
# arbadakarbA
# abdkrA
# 11

# %%
# ваше решение здесь
str = 'Abrakadabra'
print (str[2])
print (str[-2])
print (str[:5])
print (str[:-2])
print (str[::2])
print (str[1::2])
print (str[::-1])
print (str[-1::-2])
print (len(str))
# Out:
# r
# r
# Abrak
# Abrakadab
# Arkdba
# baaar
# arbadakarbA
# abdkrA
# 11

# %% [markdown]
# ## 7. Срезы списков
#
# Используя список `dwarves`, выведите на экран с помощью срезов следующие списки:
#
#     ["Двалин", "Бифур", "Бофур"]
#     ["Балин", "Бифур", "Бомбур", "Глоин", "Нори", "Фили", "Торин"]
#     ["Оин", "Дори", "Ори", "Кили"]
#     ["Торин", "Фили", "Нори", "Глоин"]

# %%
dwarves = ["Балин", "Двалин", "Бифур", "Бофур", 
         "Бомбур", "Оин", "Глоин", "Дори", "Нори",
         "Ори", "Фили", "Кили", "Торин"]

# решение здесь
print (dwarves[1:4])
print (dwarves[::2])
print (dwarves[5::2])
print (dwarves[-1:-8:-2])
# Out:
# ['Двалин', 'Бифур', 'Бофур']
# ['Балин', 'Бифур', 'Бомбур', 'Глоин', 'Нори', 'Фили', 'Торин']
# ['Оин', 'Дори', 'Ори', 'Кили']
# ['Торин', 'Фили', 'Нори', 'Глоин']

# %% [markdown]
# ### 8. Сколько чисел совпадает? (условия)
#
# Даны три целых числа. Определите, сколько среди них совпадающих. Программа должна вывести одно из чисел: 3 (если все совпадают), 2 (если два совпадает) или 0 (если все числа различны).
#
# **Формат ввода**
# Вводятся три целых числа
#
# **Формат вывода**
# Целое число

# %%
# ваше решение здесь
a = int(input())
b = int(input())
c = int(input())
if a == b and a == c:
    print (3)
elif a == b or a == c or b == c:
    print (2)
else:
    print (0)
# Out:
#  1
#  2
#  1
# 2

# %% [markdown]
# ### 9. Наименьший делитель
#
# Дано целое число, не меньшее 2. Выведите его наименьший натуральный делитель, отличный от 1.
#
# **Формат ввода**
# Вводится целое положительное число
#
# **Формат вывода**
# Выведите ответ на задачу
#
# **Пример**
#
# **Ввод**
# 15
#
# **Вывод**
# 3

# %%
# ваше решение здесь
a = int(input('Введите целое число больше 2:'))
i = 2
while i <= a:
    if (a % i) == 0:
        print ('Наименьший натуральный делитель числа, отличный от 1 равен', i)
        break
    i += 1
# Out:
# Введите целое число больше 2: 15
# Наименьший натуральный делитель числа, отличный от 1 равен 3

# %% [markdown]
# # Регулярные выражения

# %% [markdown]
# ### Задачка про аббревиатуры
# Владимир устроился на работу в одно очень важное место. И в первом же документе он ничего не понял,
# там были сплошные ФГУП НИЦ ГИДГЕО, ФГОУ ЧШУ АПК и т.п. Тогда он решил собрать все аббревиатуры, чтобы потом найти их расшифровки на http://sokr.ru/. Помогите ему.
# Будем считать аббревиатурой слова только лишь из заглавных букв (как минимум из двух). Если несколько таких слов разделены пробелами, то они
# считаются одной аббревиатурой.
#
# **Ввод**: Это курс информатики соответствует ФГОС и ПООП, это подтверждено ФГУ ФНЦ НИИСИ РАН\
# **Вывод**: ФГОС, ПООП, ФГУ ФНЦ НИИСИ РАН
#
# Регулярка должна работать для любой строки (а не толкьо для конкретного написанного тут примера!)

# %%
import re
# Ваше решение
s = 'Это курс информатики соответствует ФГОС и ПООП, это подтверждено ФГУ ФНЦ НИИСИ РАН'
print (*re.findall(r'(?<=\s)[А-ЯЁA-Z\s]{2,}(?<=[А-ЯЁA-Z][А-ЯЁA-Z])',s), sep = ', ')
# Out:
# ФГОС, ПООП, ФГУ ФНЦ НИИСИ РАН

# %% [markdown]
# ## camelCase -> camel_case
#
# Мы уже довольно много говорили про то, что в компаниях могут быть конвенции по обозначению переменных. Что, если вы написали код, а в нем переменные названы в Camel Case а вам требуется snake case? Пожалуй, стоит автоматизировать этот процесс. Попробуем написать регулярное выражение, которое этот функционал реализует
#
# **Ввод**: camelCaseVar\
# **Вывод**: camel_case_var

# %%
#Camel case to snake case
v = 'camelCaseVar'
import re
print (re.sub(r'(?=[A-Z])', '_', v).lower())
# Out:
# camel_case_var

# %% [markdown]
# ## Задачка про подсчет количества слов
#
# Слова у нас могут состоять из букв или букв, стоящих вокруг дефиса (во-первых, чуть-чуть, давай-ка). Попробуем это описать регулярным выражением

# %%
text = '''
                    - Дельный, что и говорить,
                      Был старик тот самый,
                      Что придумал суп варить
                      На колесах прямо.
                      Суп - во-первых. Во-вторых,
                      Кашу в норме прочной.
                      Нет, старик он был старик
                      Чуткий - это точно.
'''

print (len(re.findall(r'(?<=\s)(?!-)[-\w]+', text)))
# Out:
# 30

# %% [markdown]
# ### Задачка про поиск слов на а и на е
# Найдите в тексте слова, начинающиеся на а и на е

# %%
import re
# Input.
text = "The following example creates an ArrayList with a capacity of 50 elements.\
        Four elements are then added to the ArrayList and the ArrayList is trimmed accordingly."

text2 = '''
        Ihr naht euch wieder, schwankende Gestalten,
        Die früh sich einst dem trüben Blick gezeigt.
        Versuch’ ich wohl, euch diesmal festzuhalten?
        Fühl’ ich mein Herz noch jenem Wahn geneigt?
        '''
print (re.findall(r'(?<=\s)[a,e,A,E]\w*', text))
print (re.findall(r'(?<=\s)[a,e,A,E]\w*', text2))
# Out:
# ['example', 'an', 'ArrayList', 'a', 'elements', 'elements', 'are', 'added', 'ArrayList', 'and', 'ArrayList', 'accordingly']
# ['euch', 'einst', 'euch']

# %% [markdown]
# ### Давайте разберем реальный пример
#
# Возьмем перевод книги Идиот, вытащим оттуда текст первой главы, после чего посчитаем, сколько в тексте слов, содержащих апостроф, например that's (будем считать за одно слово) в строке good ol' days также одно слово. Ссылка 'https://www.gutenberg.org/files/2638/2638-0.txt'

# %%
import re
import requests

the_idiot_url = 'https://www.gutenberg.org/files/2638/2638-0.txt'
raw = requests.get(the_idiot_url).text

# Индекс начала первой главы
start = re.search(r'PART I', raw).start()
# Индекс конца первой главы
end = re.search(r'he determined to take a droshky.', raw).end()
start, end
print(raw.count("â", start, end))
# Out:
# 389

# %% [markdown]
# # А вот тут придется погуглить
#
# ## Про время
# Вовочка подготовил одно очень важное письмо, но везде указал неправильное время.
# Поэтому нужно заменить все вхождения времени на строку (TBD). Время — это строка вида HH:MM:SS или HH:MM, в которой HH — число от 00 до 23, а MM и SS — число от 00 до 59.
#
# Ввод:
#
#     Уважаемые! Если вы к 09:00 не вернёте
#     чемодан, то уже в 09:00:01 я за себя не отвечаю.
#     PS. С отношением 25:50 всё нормально!
#
# Вывод:
#
#     Уважаемые! Если вы к (TBD) не вернёте
#     чемодан, то уже в (TBD) я за себя не отвечаю.
#     PS. С отношением 25:50 всё нормально!

# %%
import re
inp = """Уважаемые! Если вы к 09:00 не вернёте 
чемодан, то уже в 09:00:01 я за себя не отвечаю 08:65. 
PS. 03:09:47 С 02:87:20 отношением 25:50 всё нормально!"""

R = inp
S = re.findall(r'(?:\d\d:\d\d:\d\d)', R)
j = 0
while j < len(S):
    if int(re.split(r':', S[j])[0]) <= 23:
        if int(re.split(r':', S[j])[1]) <= 59:
            if int(re.split(r':', S[j])[2]) <= 59:
                R = re.sub(S[j],'(TBD)', R)
    j += 1
M = re.findall(r'(?:\d\d:\d\d)', R)
i = 0
while i < len(M):
    if int(re.split(r':', M[i])[0]) <= 23:
        if int(re.split(r':', M[i])[1]) <= 59:
            R = re.sub(M[i],'(TBD)', R)
    i += 1
print (R)
# Out:
# Уважаемые! Если вы к (TBD) не вернёте
# чемодан, то уже в (TBD) я за себя не отвечаю 08:65.
# PS. (TBD) С 02:87:20 отношением 25:50 всё нормально!

# %% [markdown]
# ## Про финансовую отчетность
#
# Владимиру потребовалось срочно запутать финансовую документацию. Но так, чтобы это было обратимо.
# Он не придумал ничего лучше, чем заменить каждое целое число (последовательность цифр) на его куб. Помогите ему.
#
# Ввод:
#
#     Было закуплено 12 единиц техники
#     по 410.37 рублей.
#
# Вывод:
#
#     Было закуплено 1728 единиц техники
#     по 68921000.50653 рублей.

# %%
t = 'Было закуплено 12 единиц техники по 410.37 рублей.'
sp = re.findall(r'\d+',t)
i = 0
while i < len(sp):
    t = re.sub(sp[i], str((lambda x : x**3) (int(sp[i]))), t)
    i += 1
print (t)
# Out:
# Было закуплено 1728 единиц техники по 68921000.50653 рублей.
